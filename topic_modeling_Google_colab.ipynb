# %% [markdown]
# <a href="https://colab.research.google.com/github/MikelKN/new-phd-with-rawat/blob/main/topic_modeling_Google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://github.com/MikelKN/new-phd-with-rawat.git

# %% [markdown]
# ## Loading the data

# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import userdata
# userdata.get('secretName')
import os

os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')

# !kaggle datasets download -d elgringofrances/english-hate-speech-superset
# !kaggle datasets download -d saurabhshahane/fake-news-classification

# !unzip english-hate-speech-superset.zip
# !unzip fake-news-classification.zip
# Out:
# Mounted at /content/drive
# Dataset URL: https://www.kaggle.com/datasets/elgringofrances/english-hate-speech-superset
# License(s): MIT
# Downloading english-hate-speech-superset.zip to /content
#  22% 5.00M/22.8M [00:00<00:00, 24.3MB/s]
# 100% 22.8M/22.8M [00:00<00:00, 86.7MB/s]
# Dataset URL: https://www.kaggle.com/datasets/saurabhshahane/fake-news-classification
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading fake-news-classification.zip to /content
#  89% 82.0M/92.1M [00:00<00:00, 223MB/s]
# 100% 92.1M/92.1M [00:00<00:00, 189MB/s]
# Archive:  english-hate-speech-superset.zip
#   inflating: en_hf_102024.csv
# Archive:  fake-news-classification.zip
#   inflating: WELFake_Dataset.csv

# %% [markdown]
# ## Running the script

# %% [markdown]
# ## Notebook credit:
#
# - [Fastopics by Wu et al. 2024](https://colab.research.google.com/drive/1bduHWL5_bvsl4EYOgimCOmU-7RfnXqrX?usp=sharing)

# %%
# !pip install topmost
# !pip install fastopic
# # !pip install plotly kaleido
# !pip install -U kaleido
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# limit to the lenght of token that should be displayed on the daatsets
pd.options.display.max_colwidth = 500

import os
import pandas as pd
import kaggle
import kagglehub
import matplotlib.pyplot as plt
# import plotly

import topmost
from fastopic import FASTopic

# from IPython.display import display

class Read:
    @staticmethod
    def read_and_filter_dataset (filepath, text_column, max_length=1000):
        data = pd.read_csv(filepath, low_memory=False)
        # Filter rows based on text length
        data = data[data[text_column].str.len() <= max_length]
        return data

class Topic():
    def __init__(self, num_topics=50):
        self.num_topics = num_topics
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {self.device}")

    def topic_modelling(self, dataset, dataset_name, text):
        # Select the first 100 rows of the 'text' column
        docs = dataset[text].tolist()

        # Initialize and fit the topic model
        topic_model = FASTopic(num_topics=self.num_topics, verbose=True)
        topic_top_words, doc_topic_dist = topic_model.fit_transform(docs)

        # Visualize topic hierarchy and topic weights
        fig_hierarchy = topic_model.visualize_topic_hierarchy()
        fig_hierarchy.show()
        # fig_hierarchy.write_image(hierarchy_filename)

        fig_weights = topic_model.visualize_topic_weights(top_n=20, height=500)
        fig_weights.show()

        return topic_top_words, doc_topic_dist, fig_hierarchy, fig_weights

def main():
    reader= Read()
    topic_model = Topic()

    # Authenticate with Kaggle API
    kaggle.api.authenticate()

    print('\nUploading and reading the datasets starts!')

    # Read the CSV files into DataFrames
    hate_speech = reader.read_and_filter_dataset('/content/en_hf_102024.csv', 'text')
    fake_news = reader.read_and_filter_dataset('/content/WELFake_Dataset.csv', 'text')

    # Drop missing values
    fake_news.dropna(inplace=True)
    hate_speech.dropna(inplace=True)


    # Extract DataFrame to include only rows with label = 1
    hate_speech_super_df = hate_speech.loc[hate_speech['labels'] == 1, ['text', 'labels']].sample(n=6000, random_state=42).reset_index(drop=True)
    fake_news_df = fake_news.loc[fake_news['label'] == 1, ['text', 'label']].sample(n=6000, random_state=42).reset_index(drop=True)

    print('\n')
    print('Dataset reader completed!')
    print('\n')

    print('Starting senitment analysis!')
    print('\n')

    print('The code for topic modelling begins here...!')
    print('\n')

    top_topics_fake, topic_distribution_fake, figure_heirarchy_fake, figure_weights_fake = topic_model.topic_modelling (fake_news_df, 'fake_news', 'text')
    top_topics_hate, topic_distribution_hate, figure_heirarchy_hate, figure_weights_hate = topic_model.topic_modelling (hate_speech_super_df,"hate_speech", 'text')

    print('\n')
    print("Script Has finished running!")

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: topmost in /usr/local/lib/python3.10/dist-packages (0.0.5)
# Requirement already satisfied: numpy<1.27.0 in /usr/local/lib/python3.10/dist-packages (from topmost) (1.26.4)
# Requirement already satisfied: scipy<=1.10.1 in /usr/local/lib/python3.10/dist-packages (from topmost) (1.10.1)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from topmost) (2.7.0)
# Requirement already satisfied: torchvision>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from topmost) (0.20.1+cu121)
# Requirement already satisfied: gensim>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from topmost) (4.3.3)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from topmost) (1.5.2)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.10/dist-packages (from topmost) (4.66.6)
# Requirement already satisfied: fastopic>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from topmost) (0.0.5)
# Requirement already satisfied: bertopic>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from topmost) (0.16.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost) (0.8.39)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost) (5.24.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost) (0.5.7)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->topmost) (7.0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->topmost) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->topmost) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost) (4.46.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (1.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic>=0.15.0->topmost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic>=0.15.0->topmost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic>=0.15.0->topmost) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic>=0.15.0->topmost) (9.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim>=4.2.0->topmost) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (0.20.3)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic>=0.15.0->topmost) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic>=0.15.0->topmost) (0.5.13)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic>=0.15.0->topmost) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic>=0.15.0->topmost) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost) (2024.8.30)
# Requirement already satisfied: fastopic in /usr/local/lib/python3.10/dist-packages (0.0.5)
# Requirement already satisfied: topmost>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from fastopic) (0.0.5)
# Requirement already satisfied: numpy<1.27.0 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (1.26.4)
# Requirement already satisfied: scipy<=1.10.1 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (1.10.1)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (2.7.0)
# Requirement already satisfied: torchvision>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (0.20.1+cu121)
# Requirement already satisfied: gensim>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (4.3.3)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (1.5.2)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (4.66.6)
# Requirement already satisfied: bertopic>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from topmost>=0.0.5->fastopic) (0.16.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost>=0.0.5->fastopic) (0.8.39)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost>=0.0.5->fastopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost>=0.0.5->fastopic) (5.24.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic>=0.15.0->topmost>=0.0.5->fastopic) (0.5.7)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.2.0->topmost>=0.0.5->fastopic) (7.0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->topmost>=0.0.5->fastopic) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->topmost>=0.0.5->fastopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (4.46.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (1.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (9.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim>=4.2.0->topmost>=0.0.5->fastopic) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (0.20.3)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (0.5.13)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic>=0.15.0->topmost>=0.0.5->fastopic) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.6.0->topmost>=0.0.5->fastopic) (2024.8.30)
# Using device: cuda
#
# Uploading and reading the datasets starts!
# 2024-11-18 08:34:37,335 - FASTopic - use device: cuda
# Dataset reader completed!
#
#
# Starting senitment analysis!
#
#
# The code for topic modelling begins here...!
# loading train texts: 100%|██████████| 60/60 [00:00<00:00, 5069.05it/s]
# parsing texts: 100%|██████████| 60/60 [00:00<00:00, 5077.54it/s]
# 2024-11-18 08:34:38,249 - TopMost - Real vocab size: 1624
# 2024-11-18 08:34:38,250 - TopMost - Real training size: 60 	 avg length: 61.750
# Training FASTopic:   4%|▍         | 8/200 [00:00<00:02, 64.48it/s]2024-11-18 08:34:38,604 - FASTopic - Epoch: 010 loss: 455.652
# Training FASTopic:   8%|▊         | 15/200 [00:00<00:04, 41.49it/s]2024-11-18 08:34:38,969 - FASTopic - Epoch: 020 loss: 432.913
# Training FASTopic:  14%|█▍        | 28/200 [00:00<00:06, 26.12it/s]2024-11-18 08:34:39,424 - FASTopic - Epoch: 030 loss: 385.052
# Training FASTopic:  18%|█▊        | 37/200 [00:01<00:06, 25.36it/s]2024-11-18 08:34:39,857 - FASTopic - Epoch: 040 loss: 352.167
# Training FASTopic:  24%|██▍       | 49/200 [00:01<00:06, 22.53it/s]2024-11-18 08:34:40,315 - FASTopic - Epoch: 050 loss: 332.058
# Training FASTopic:  29%|██▉       | 58/200 [00:02<00:06, 22.35it/s]2024-11-18 08:34:40,748 - FASTopic - Epoch: 060 loss: 320.175
# Training FASTopic:  34%|███▎      | 67/200 [00:02<00:05, 23.76it/s]2024-11-18 08:34:41,153 - FASTopic - Epoch: 070 loss: 313.807
# Training FASTopic:  40%|███▉      | 79/200 [00:03<00:05, 23.78it/s]2024-11-18 08:34:41,581 - FASTopic - Epoch: 080 loss: 309.665
# Training FASTopic:  44%|████▍     | 88/200 [00:03<00:04, 24.20it/s]2024-11-18 08:34:41,991 - FASTopic - Epoch: 090 loss: 306.527
# Training FASTopic:  48%|████▊     | 97/200 [00:03<00:04, 23.85it/s]2024-11-18 08:34:42,420 - FASTopic - Epoch: 100 loss: 304.185
# Training FASTopic:  55%|█████▍    | 109/200 [00:04<00:03, 24.41it/s]2024-11-18 08:34:42,826 - FASTopic - Epoch: 110 loss: 302.323
# Training FASTopic:  59%|█████▉    | 118/200 [00:04<00:03, 24.08it/s]2024-11-18 08:34:43,250 - FASTopic - Epoch: 120 loss: 300.637
# Training FASTopic:  64%|██████▎   | 127/200 [00:05<00:03, 23.79it/s]2024-11-18 08:34:43,672 - FASTopic - Epoch: 130 loss: 299.136
# Training FASTopic:  70%|██████▉   | 139/200 [00:05<00:02, 24.41it/s]2024-11-18 08:34:44,082 - FASTopic - Epoch: 140 loss: 297.678
# Training FASTopic:  74%|███████▍  | 148/200 [00:06<00:02, 23.13it/s]2024-11-18 08:34:44,512 - FASTopic - Epoch: 150 loss: 296.286
# Training FASTopic:  78%|███████▊  | 157/200 [00:06<00:01, 24.21it/s]2024-11-18 08:34:44,918 - FASTopic - Epoch: 160 loss: 294.991
# Training FASTopic:  84%|████████▍ | 169/200 [00:06<00:01, 23.72it/s]2024-11-18 08:34:45,342 - FASTopic - Epoch: 170 loss: 293.678
# Training FASTopic:  89%|████████▉ | 178/200 [00:07<00:01, 18.93it/s]2024-11-18 08:34:45,928 - FASTopic - Epoch: 180 loss: 292.458
# Training FASTopic:  94%|█████████▍| 188/200 [00:07<00:00, 18.00it/s]2024-11-18 08:34:46,533 - FASTopic - Epoch: 190 loss: 291.406
# Training FASTopic:  99%|█████████▉| 198/200 [00:08<00:00, 15.57it/s]2024-11-18 08:34:47,159 - FASTopic - Epoch: 200 loss: 290.443
# Training FASTopic: 100%|██████████| 200/200 [00:08<00:00, 22.90it/s]
# Topic 0: waters maxine jury talking matter dershowitz grand racist know ought racists alan calling better race
# Topic 1: california falwell those specifically deplorable complete int taking lie sitting liberty jerry muslims referring tell
# Topic 2: ease arguments smith plight reject final answer less intellectual enormous song rebekah subtle bury universal
# Topic 3: hitler germany attempting reminds spent raid clean journal shut else born infowarsif anything dusseldorf lived
# Topic 4: veterans bus cinquina rodgers hospital arnaldo jersey health together then everybody care fortunate legion problems
# Topic 5: tehran aerospace exhibition hamid international products javanipress underway capital showcase milad event catching javani iconic
# Topic 6: register ivanka voting eric didn york deadline advance votes guess guilty unaware win weekthe missed
# Topic 7: sign front please take business until out you will because country does stop received dawn
# Topic 8: campaign fundraisers barry miss end dinner home clinton there received want tmz hrc creator secret
# Topic 9: visso drone http reply central hurt measured caused italy borgo fled tremor felt shortly footage
# Topic 10: commentary payback aww poor boston bobblehead bitch january pictwittercom going weakens wasn throws sensation ham
# Topic 11: conducted build chossudovsky borders natos globalization expansion research europe montreal eastward williams ian focus eastern
# Topic 12: air aircraft traffic statement establish controllers incident follow were bloomberg fighters immediately communications communication authorities
# Topic 13: podcast travel listen men favorite itunes think discuss prescribing rating modern benefits phenomenon role mistaken
# Topic 14: someone speaker bot transcript fantastic pastor gave user burns emoji programmers blm typing swipe drive
# Topic 15: nice anyhow anti sorry endorsing voanews hand loving backed thanked thanking screw shook couldn colors
# Topic 16: plan economy courage repeal affordable act speech congress voted care major health thing members because
# Topic 17: justice ginsburg scalia allegheny carolina senate senator lindsey graham hope work women members south college
# Topic 18: elderly medicare use scammers below information pertinent fraud personal obtain unsuspecting impersonating nptelegraphcom prey alerts
# Topic 19: ace man rips rosen frightening lyons regime honestly james patriot meant retired missing benghazi general
# Topic 20: true higbie carl let credibility believe truth right say not yikes shouldn lock anchor just
# Topic 21: parton started charges supporter idol deceitful urged fooled criminal nominee stay feeling refusing doing now
# Topic 22: thaaat snarky june need see handles coffee small positive questions though thumb goes print melania
# Topic 23: ignorance political ignorant leaders hooper series mike mexico explains roccarocca results civic politically stuart holding
# Topic 24: symbol federal canoe seems cultural radio genocide cnn because white claimed them promote mins street
# Topic 25: russian missile sarmat texas france wars rocket weapon design capable state published reported image poles
# Topic 26: clearance trail status whopping buzz estate service guy elbows furstenberg rub donations seating attendit tmz
# Topic 27: wing friends loosely trial indict responded sandwich matters indictment nobody msnbc unloaded inappropriately calls petit
# Topic 28: account comment insert sphere twitter yoko once taken monumental again ono works disqus wwwyoutubecom dwzza
# Topic 29: media cant oct lose stages self saturday denial pray hbd archive generally control destruct tweets
# Topic 30: affleck islam leftist ben admittedly deflate typically wondering intentionally eyed interviews off movies haven warning
# Topic 31: https morally values appropriation misao yoga heat set ordinary identity kind privileged accused reek ascribe
# Topic 32: antharrison entitled mooch entered intel changed nothing ambition fundamentally outside thanks ticker nov posted stories
# Topic 33: oregon surrounded protesters tyrannical ever building stelter agents rodericktold art protest brian enforcement explained property
# Topic 34: clueless dear since even grow running cheated smoke cruise beginning confront cheat shoot worse job
# Topic 35: syria syrian touch blame conflict gore those alarmist following wire century driving london finally shifts
# Topic 36: might changes making pro gotta key moore lower turn include revitalizing growth unveil promised liberals
# Topic 37: line luntz frank undecided independent when voters question talks bed september tracking speaksthis unbelievable watch
# Topic 38: propaganda party truth would agenda thought which right their promote evidence age george wrong corporations
# Topic 39: big misunderstanding misspoke probably sexual likely kinda relations bill did senators others labeled goodwill ways
# Topic 40: demo context demonstration harris found uses bev mechanism theft devastating explanation system yet election real
# Topic 41: pursued husband described narcissistic girl pleasuring influential monica sex looney old advisor uncensored young blair
# Topic 42: policy foreign stephen expert washington explain zunes difference issues interested crosstalk henningsen narrowing faraci minds
# Topic 43: social struck gmt quake some local buildings around been day comments mins street agency across
# Topic 44: way supporting polling usual corporate data notice hate interest believes occupies groups putting politics sxqnzdl
# Topic 45: obama sanders bernie still candidate week through house hours barack white voice played came decided
# Topic 46: alternative information too scumbags creepy bit entertaining group agitators click here dave weiner congressman hodges
# Topic 47: person same devices fema able peoples emergency youtuber dahboo whereabouts intellihub ping type forced locate
# Topic 48: sheeple airport wwwthedailysheeplecom daily detroit full security give encourage miserable contributed republish digital gladly airports
# Topic 49: griffin deserves alongside bloom donald her coming salon erratic posing disturbing list lisa course backlash
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="21f1b84d-3e15-466c-8ac1-1cc2f41e81e8" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21f1b84d-3e15-466c-8ac1-1cc2f41e81e8")) {                    Plotly.newPlot(                        "21f1b84d-3e15-466c-8ac1-1cc2f41e81e8",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.9371758152591227,3.9371758152591227,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,4.325056331685987,4.325056331685987,3.9371758152591227],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,4.740268596430262,4.740268596430262,4.325056331685987],"xaxis":"x","y":[-5.0,-5.0,-22.5,-22.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.650983295174507,3.650983295174507,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.650983295174507,4.034406212557981,4.034406212557981,0.0],"xaxis":"x","y":[-50.0,-50.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.759897085971558,3.759897085971558,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.995637829837522,3.995637829837522,3.759897085971558],"xaxis":"x","y":[-75.0,-75.0,-90.0,-90.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.8660517998016615,3.8660517998016615,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.936739565260283,3.936739565260283,3.8660517998016615],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.995637829837522,4.261909529753723,4.261909529753723,3.936739565260283],"xaxis":"x","y":[-82.5,-82.5,-112.5,-112.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.6846540586180327,3.6846540586180327,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.6846540586180327,4.277508764165527,4.277508764165527,0.0],"xaxis":"x","y":[-140.0,-140.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[4.261909529753723,4.676158144930957,4.676158144930957,4.277508764165527],"xaxis":"x","y":[-97.5,-97.5,-147.5,-147.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[4.034406212557981,5.134532977204693,5.134532977204693,4.676158144930957],"xaxis":"x","y":[-57.5,-57.5,-122.5,-122.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.177739218517174,3.177739218517174,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,4.013578859610269,4.013578859610269,3.177739218517174],"xaxis":"x","y":[-165.0,-165.0,-180.0,-180.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.5706586533523974,3.57065865 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="acec9c64-2639-46b7-8a5f-46a279e4bf09" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acec9c64-2639-46b7-8a5f-46a279e4bf09")) {                    Plotly.newPlot(                        "acec9c64-2639-46b7-8a5f-46a279e4bf09",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.019676290452480316,0.01987273618578911,0.020391155034303665,0.020572278648614883,0.020661186426877975,0.021064545959234238,0.021232839673757553,0.02155689150094986,0.021734006702899933,0.02230982482433319,0.022694997489452362,0.02277687005698681,0.023463506251573563,0.023662785068154335,0.024081768468022346,0.0254498403519392,0.026927458122372627,0.03222750499844551,0.032685719430446625,0.03431493043899536],"y":["21_parton_started_charges_supporter_idol","42_policy_foreign_stephen_expert_washington","17_justice_ginsburg_scalia_allegheny_carolina","35_syria_syrian_touch_blame_conflict","49_griffin_deserves_alongside_bloom_donald","28_account_comment_insert_sphere_twitter","38_propaganda_party_truth_would_agenda","19_ace_man_rips_rosen_frightening","32_antharrison_entitled_mooch_entered_intel","1_california_falwell_those_specifically_deplorable","46_alternative_information_too_scumbags_creepy","45_obama_sanders_bernie_still_candidate","22_thaaat_snarky_june_need_see","44_way_supporting_polling_usual_corporate","24_symbol_federal_canoe_seems_cultural","14_someone_speaker_bot_transcript_fantastic","20_true_higbie_carl_let_credibility","7_sign_front_please_take_business","37_line_luntz_frank_undecided_independent","16_plan_economy_courage_repeal_affordable"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.77777777777777 ...
# 2024-11-18 08:34:47,748 - FASTopic - use device: cuda
# loading train texts: 100%|██████████| 60/60 [00:00<00:00, 2346.07it/s]
# parsing texts: 100%|██████████| 60/60 [00:00<00:00, 12599.29it/s]
# 2024-11-18 08:34:48,689 - TopMost - Real vocab size: 626
# 2024-11-18 08:34:48,693 - TopMost - Real training size: 60 	 avg length: 18.717
# Training FASTopic:   2%|▎         | 5/200 [00:00<00:04, 40.71it/s]2024-11-18 08:34:49,639 - FASTopic - Epoch: 010 loss: 122.545
# Training FASTopic:  10%|▉         | 19/200 [00:01<00:18,  9.91it/s]2024-11-18 08:34:50,744 - FASTopic - Epoch: 020 loss: 117.930
# Training FASTopic:  14%|█▎        | 27/200 [00:02<00:16, 10.68it/s]2024-11-18 08:34:51,504 - FASTopic - Epoch: 030 loss: 108.547
# Training FASTopic:  20%|█▉        | 39/200 [00:03<00:08, 19.75it/s]2024-11-18 08:34:51,922 - FASTopic - Epoch: 040 loss: 98.691
# Training FASTopic:  24%|██▍       | 48/200 [00:03<00:06, 22.60it/s]2024-11-18 08:34:52,338 - FASTopic - Epoch: 050 loss: 90.224
# Training FASTopic:  28%|██▊       | 57/200 [00:03<00:06, 23.66it/s]2024-11-18 08:34:52,747 - FASTopic - Epoch: 060 loss: 83.943
# Training FASTopic:  34%|███▍      | 69/200 [00:04<00:05, 23.21it/s]2024-11-18 08:34:53,189 - FASTopic - Epoch: 070 loss: 79.607
# Training FASTopic:  39%|███▉      | 78/200 [00:04<00:05, 23.61it/s]2024-11-18 08:34:53,612 - FASTopic - Epoch: 080 loss: 76.699
# Training FASTopic:  44%|████▎     | 87/200 [00:05<00:04, 23.44it/s]2024-11-18 08:34:54,027 - FASTopic - Epoch: 090 loss: 74.830
# Training FASTopic:  50%|████▉     | 99/200 [00:05<00:04, 23.43it/s]2024-11-18 08:34:54,460 - FASTopic - Epoch: 100 loss: 73.482
# Training FASTopic:  54%|█████▍    | 108/200 [00:05<00:03, 24.14it/s]2024-11-18 08:34:54,880 - FASTopic - Epoch: 110 loss: 72.487
# Training FASTopic:  58%|█████▊    | 117/200 [00:06<00:03, 24.12it/s]2024-11-18 08:34:55,293 - FASTopic - Epoch: 120 loss: 71.720
# Training FASTopic:  64%|██████▍   | 129/200 [00:06<00:02, 24.23it/s]2024-11-18 08:34:55,704 - FASTopic - Epoch: 130 loss: 71.041
# Training FASTopic:  69%|██████▉   | 138/200 [00:07<00:02, 24.08it/s]2024-11-18 08:34:56,120 - FASTopic - Epoch: 140 loss: 70.462
# Training FASTopic:  74%|███████▎  | 147/200 [00:07<00:02, 23.95it/s]2024-11-18 08:34:56,535 - FASTopic - Epoch: 150 loss: 69.966
# Training FASTopic:  80%|███████▉  | 159/200 [00:08<00:01, 23.59it/s]2024-11-18 08:34:56,968 - FASTopic - Epoch: 160 loss: 69.524
# Training FASTopic:  84%|████████▍ | 168/200 [00:08<00:01, 23.43it/s]2024-11-18 08:34:57,390 - FASTopic - Epoch: 170 loss: 69.141
# Training FASTopic:  88%|████████▊ | 177/200 [00:08<00:00, 24.16it/s]2024-11-18 08:34:57,801 - FASTopic - Epoch: 180 loss: 68.789
# Training FASTopic:  94%|█████████▍| 189/200 [00:09<00:00, 23.97it/s]2024-11-18 08:34:58,225 - FASTopic - Epoch: 190 loss: 68.476
# Training FASTopic:  99%|█████████▉| 198/200 [00:09<00:00, 23.84it/s]2024-11-18 08:34:58,653 - FASTopic - Epoch: 200 loss: 68.179
# Training FASTopic: 100%|██████████| 200/200 [00:09<00:00, 20.43it/s]
# Topic 0: number many muslim kill how yesterday per year takes wonder democrats will terrorist killed terrorists
# Topic 1: sounds chief chitownboystownbathhouseboi rahm emmanuel alinskyite looks kike like that insensitive disprove any shot cop
# Topic 2: big cheeto ever miss ignorant worst president meant wished ripdonaldtrump matter death rest despise him
# Topic 3: sympathy said exactly done receive mind should have boycottchina wuhanvirus spanish flu what chinese you
# Topic 4: perps towelhead had radar police course did nothing about got now will battle angry nest
# Topic 5: ass america entity chill upstairs realm god dark hate let niggers something from like but
# Topic 6: strong comrades enough females without endangering combat self most sensitive relative positions liked extremely last
# Topic 7: wuhan knocking originated doors criminal lab communist every country chinesevirus link coming from this chinavirus
# Topic 8: million uyghurs decided recently han video definitely among forcing across manufacturing provinces sent works people
# Topic 9: wakes doing problem resolve usa way blame been years this never chinese has but chinavirus
# Topic 10: wuflu wuhancoronavirusoutbreak chinalies failed proof evidence best chinazi boycottchina how anticcp save implement failedstate measures
# Topic 11: jews start grimey filthy christmas friend jesus murdered kind holiday tho gonna christ filled calling
# Topic 12: under made microscope awfully hand suspicious electron bioweapon coffee attacked western cup chinesevirus looks been
# Topic 13: allowed who mers hatred doesnt change destroy support flu spanish spread trump virus fact wuhancoronavirusoutbreak
# Topic 14: stab would fight fair something try one just now its nigger operation dramatically local london
# Topic 15: must anyway still luck rationale scientific first chickens new coincidence next horrible found infects needs
# Topic 16: animals buy phones sought contain dogs cats coronapocalypse might domestic wildlife imported infected products etc
# Topic 17: planet regime depraved evil fault tedros coming call from most now chinavirus your and integrity
# Topic 18: tranny bathrooms edition swear youd church riot take moslem feminazi within distribution firearms improved francis
# Topic 19: being uncaring holding last extremely liked positions relative sensitive manipulated have governmental dangerous voting destroyers
# Topic 20: fails sick collect tax wipe asians too genes island her genetic commie bumper seed revenues
# Topic 21: coronachan prefer wuhanflu coronaviruses coronadeath man spreading corona products infected wildlife imported domestic sought dogs
# Topic 22: know which she worse huma radical hrc sharialaw islamic yourpizzascooked anyone love terrorists what think
# Topic 23: hogs cattle needs new bad horrible found infects scientific next coincidence chickens first rationale luck
# Topic 24: hell can kong own making make yes human recent examples freedoms mistakes keeps suppressing rights
# Topic 25: palin diddled sarah look because raped does calling christ holiday gonna jesus murdered tho filled
# Topic 26: your trayvon comprehend footage than brain other theory ontop bodycam tell could dumb beating cop
# Topic 27: call there get started ebola faces nitwits schlong goat hotline was their these out when
# Topic 28: person immediately harder listening labeled woman lived experiences here patriarchy lot believing feminazi theres being
# Topic 29: jong kim dindunuffin learned racist ease satanic voting destroyers through wave francis confederate guerilla tortured
# Topic 30: coach men wnba nba dont fact let sexist think should women like but going fit
# Topic 31: voted percent coons flag back nest angry battle against moore confederate through wave him white
# Topic 32: fuck muzzies all their fucking say khan french islam douchebags resistance europe public scums earth
# Topic 33: lams carrielam manages measures failedstate enraged implement save anticcp antiepidemic chinazivirus tough lam hkers malfeasance
# Topic 34: freeworld pandemics deadly unleashing coronapocolypse mondaythoughts chinesecommunistpartyvirus hold communistchina chinesecoronavirus responsible quarantinelife coronavirus coronavirusupdates wuhancoronavirus
# Topic 35: suffering starts blooded scientists identifying disgusting donated cold twist propaganda chinaisasshoe helping help countries rejected
# Topic 36: also chinacoronavirus died policy wuhanpneumonia due around ccp people suffer brutally user tough chinazivirus the
# Topic 37: stuck forever breasts few movies grownup kid forget saw those never with was one that
# Topic 38: lol buck trash fine example ravens stuff where niggers nigger dumb theory could ontop beating
# Topic 39: sam win warfare boy cia accomplishes improved firearms distribution within really francis guerilla following cull
# Topic 40: amy others lampanelli funny arent suck period comics lisa shumer couple sexist most women but
# Topic 41: jerusalem attack traffic arab obama car random terror israel infringement schooled faggot call now tortured
# Topic 42: liar dollars sand profitmonger gab pajeet duped fam confirmed fat censor kike thousands fucking trump
# Topic 43: anything womans ultimate swerve broad position single hope try sexist dangerous governmental but manipulated not
# Topic 44: narrative outrage african woke international south right plaasmoorde farmers savages going fit years tortured thousands
# Topic 45: another leaders underground revolution refuse germany earth guillotine time merkel public executions resistance douchebags khan
# Topic 46: libtard swede wish someone refugees arrest rape statutory children either goes both down say moslem
# Topic 47: amp suffer world brutally suppressing making make own kong hong yes keeps examples mistakes human
# Topic 48: accountability chutiya weapon biological thats hates developed army shameful honesty atleast integrity spread virus coronavirus
# Topic 49: sue cultural fuckchina exporting irresponsible appropriation such unintellectual shameless property wuhancoronavirus nation their for user
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="774a7cef-52f2-453c-8da7-9bc6d7d98276" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("774a7cef-52f2-453c-8da7-9bc6d7d98276")) {                    Plotly.newPlot(                        "774a7cef-52f2-453c-8da7-9bc6d7d98276",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.6121222859136055,3.6121222859136055,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.352820245512115,3.352820245512115,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.5784736126861585,3.5784736126861585,3.352820245512115],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.5784736126861585,3.881500276291848,3.881500276291848,0.0],"xaxis":"x","y":[-32.5,-32.5,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.6121222859136055,4.03015857704381,4.03015857704381,3.881500276291848],"xaxis":"x","y":[-10.0,-10.0,-43.75,-43.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,2.3502425472680626,2.3502425472680626,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.028218479071292,3.028218479071292,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.7538957822105496,3.7538957822105496,3.028218479071292],"xaxis":"x","y":[-85.0,-85.0,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.6104221448936076,3.6104221448936076,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.700788636118743,3.700788636118743,3.6104221448936076],"xaxis":"x","y":[-115.0,-115.0,-130.0,-130.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,2.9914023487059724,2.9914023487059724,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.700788636118743,4.178518913644562,4.178518913644562,2.9914023487059724],"xaxis":"x","y":[-122.5,-122.5,-150.0,-150.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.7538957822105496,4.474216545109104,4.474216545109104,4.178518913644562],"xaxis":"x","y":[-92.5,-92.5,-136.25,-136.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.323717685349387,3.323717685349387,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,3.5923503049009193,3.5923503049009193,3.323717685349387],"xaxis":"x","y":[-165.0,-165.0,-180.0,-180.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[3.5923503049009193,3.834816503863381,3.834816503863381,0.0],"xaxis":"x","y":[-172.5,-172.5,-195.0,-195.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[4.474216545109104,4.5078380941 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fda334f6-3253-4b27-a079-8b51307042f0" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fda334f6-3253-4b27-a079-8b51307042f0")) {                    Plotly.newPlot(                        "fda334f6-3253-4b27-a079-8b51307042f0",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.01961279846727848,0.019900230690836906,0.020101377740502357,0.02056274563074112,0.02080385759472847,0.02135429158806801,0.021670756861567497,0.02192694880068302,0.023084362968802452,0.023541808128356934,0.023587509989738464,0.024007391184568405,0.025621037930250168,0.02610143832862377,0.02664817124605179,0.02828332595527172,0.028554365038871765,0.028941605240106583,0.029045870527625084,0.029233520850539207],"y":["26_your_trayvon_comprehend_footage_than","44_narrative_outrage_african_woke_international","25_palin_diddled_sarah_look_because","17_planet_regime_depraved_evil_fault","49_sue_cultural_fuckchina_exporting_irresponsible","5_ass_america_entity_chill_upstairs","2_big_cheeto_ever_miss_ignorant","0_number_many_muslim_kill_how","11_jews_start_grimey_filthy_christmas","38_lol_buck_trash_fine_example","1_sounds_chief_chitownboystownbathhouseboi_rahm_emmanuel","32_fuck_muzzies_all_their_fucking","27_call_there_get_started_ebola","18_tranny_bathrooms_edition_swear_youd","36_also_chinacoronavirus_died_policy_wuhanpneumonia","28_person_immediately_harder_listening_labeled","39_sam_win_warfare_boy_cia","3_sympathy_said_exactly_done_receive","42_liar_dollars_sand_profitmonger_gab","31_voted_percent_coons_flag_back"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b" ...
# Script Has finished running!
